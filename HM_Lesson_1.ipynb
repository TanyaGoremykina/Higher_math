# %%
## 1. Вычислите

## Ответ:
## [45 90
##  63  108
##  101,7 45
##  225 270]

# %%
## 2.1. Решите систему уравнений
## Ответ:
## х = 1, y = 3, z = 2
## Линейная или нелинейная это система? ДА
## А каждое уравнение по отдельности? ДА

# %%
## 2.2. Решите систему уравнений
## Ответ:
## x = корень квадратный из 1,5
## y = 5 * корень квадратный из 1,5
## Линейная или нелинейная это система? НЕТ
## А каждое уравнение по отдельности? НЕТ

# %%
## 3. Площадь пола прямоугольной комнаты равна 48 м2,а его периметр равен 28 м. Найдите длину и ширину комнаты. 

## Ответ: длина 8 м, ширина 6 м

# %%
## 4. Постройте на одном графике две кривые y(x) для функции двух переменной y(k,x)=cos(k∙x),
## взяв для одной кривой значение k=1, а для другой – любое другое k, не равное 1.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5, 5, 201)
plt.plot(x, np.cos(x), label="cos(x)")
plt.plot(x, np.cos(3*x), label="cos(3x)")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
